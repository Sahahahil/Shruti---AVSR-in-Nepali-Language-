# %%
import os
import math
import json
import random
from dataclasses import dataclass, field
from typing import Optional, Dict, Any, List, Tuple

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
from datasets import Dataset, Audio
from transformers import (
    Wav2Vec2Model,
    Wav2Vec2Processor,
    Wav2Vec2FeatureExtractor,
    Wav2Vec2CTCTokenizer,
    Trainer,
    TrainingArguments,
)
# Remove load_metric as it's deprecated - use evaluate library instead
from evaluate import load

# %%
# Optional imports for augmentation
try:
    import torchaudio
    TORCHAUDIO_AVAILABLE = True
except Exception:
    TORCHAUDIO_AVAILABLE = False

try:
    import librosa
    LIBROSA_AVAILABLE = True
except Exception:
    LIBROSA_AVAILABLE = False

# %%
# ---------------------------
# Config (edit to your paths)
# ---------------------------
TSV_PATH = "/home/sahil_duwal/MajorProject/Dataset/ne_np_female/line_index.tsv"
AUDIO_BASE = "/home/sahil_duwal/MajorProject/Dataset/ne_np_female/wavs/"
TOKENIZER_DIR = "./tokenizer_nepali"
PRETRAINED_W2V = "/home/sahil_duwal/MajorProject/Shruti---AVSR-in-Nepali-Language-/nep-2/wav2vec2-nepali-finetuned-v2"
OUTPUT_DIR = "./wav2vec2_custom_head"
SAMPLE_RATE = 16000
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# Flags
FREEZE_W2V = True
USE_ADAPTERS = True
ADAPTER_BOTTLENECK = 128
CUSTOM_TRANSFORMER_LAYERS = 4
CUSTOM_TRANSFORMER_DIM = 768
CUSTOM_TRANSFORMER_HEADS = 8
DROPOUT = 0.1
USE_SPEC_AUG = True
USE_AUDIO_AUG = True

# Training hyperparams
EPOCHS = 20
LR = 1e-4  # Reduced from 3e-4
BATCH_SIZE = 1  # Reduced from 2

# %%
# ---------------------------
# Utilities: tokenizer + processor
# ---------------------------
def load_or_create_tokenizer(tsv_path: str, tokenizer_dir: str):
    os.makedirs(tokenizer_dir, exist_ok=True)
    vocab_file = os.path.join(tokenizer_dir, "vocab.json")
    
    if os.path.exists(vocab_file):
        try:
            with open(vocab_file, 'r', encoding='utf-8') as f:
                vocab_dict = json.load(f)
            
            tokenizer = Wav2Vec2CTCTokenizer(
                vocab_file,
                unk_token="<unk>",
                pad_token="<pad>",
                word_delimiter_token="|"
            )
            return tokenizer
        except Exception as e:
            print(f"Loading existing tokenizer failed: {e}")

    # Create character-level tokenizer for CTC
    import pandas as pd
    df = pd.read_csv(tsv_path, sep="\t", low_memory=False)
    
    print(f"Available columns in TSV: {df.columns.tolist()}")
    
    # Find text column
    text_column = None
    possible_text_cols = ['text', 'transcription', 'transcript', 'sentence', 'label']
    for col in possible_text_cols:
        if col in df.columns:
            text_column = col
            break
    
    if text_column is None and len(df.columns) >= 2:
        text_column = df.columns[1]
        print(f"Using second column '{text_column}' as text data")
    
    texts = df[text_column].astype(str).tolist()
    
    # Build character-level vocabulary
    chars = set()
    for text in texts:
        chars.update(text.lower())
    
    # FIXED: Create vocabulary with proper CTC blank token
    # CTC needs: [blank, other_tokens...]
    vocab_list = ['<blank>', '<unk>', '<pad>'] + sorted(list(chars))
    vocab_dict = {char: i for i, char in enumerate(vocab_list)}
    
    # Save vocabulary
    with open(vocab_file, 'w', encoding='utf-8') as f:
        json.dump(vocab_dict, f, ensure_ascii=False, indent=2)
    
    # Create tokenizer with proper blank token
    tokenizer = Wav2Vec2CTCTokenizer(
        vocab_file,
        unk_token="<unk>",
        pad_token="<pad>",
        word_delimiter_token="|"
    )
    
    return tokenizer

# %%
# ---------------------------
# Data augmentation helpers
# ---------------------------
def speed_perturb(wave: np.ndarray, sr: int, factors=(0.9, 1.0, 1.1)) -> np.ndarray:
    if not LIBROSA_AVAILABLE:
        return wave
    f = random.choice(factors)
    if f == 1.0:
        return wave
    return librosa.effects.time_stretch(wave, rate=f)

def pitch_shift(wave: np.ndarray, sr: int, n_steps=(-2, 0, 2)) -> np.ndarray:
    if not LIBROSA_AVAILABLE:
        return wave
    step = random.choice(n_steps)
    return librosa.effects.pitch_shift(wave, sr, n_steps=step)

def add_background_noise(wave: np.ndarray, snr_db_min=5, snr_db_max=20) -> np.ndarray:
    rms = np.sqrt(np.mean(wave**2))
    if rms == 0:
        return wave
    snr_db = random.uniform(snr_db_min, snr_db_max)
    snr = 10 ** (snr_db / 20.0)
    noise_rms = rms / snr
    noise = np.random.normal(0, noise_rms, wave.shape)
    return wave + noise

def spec_augment(features: torch.Tensor, time_mask_param=30, freq_mask_param=13, num_time_masks=2, num_freq_masks=2):
    B, T, D = features.shape
    for _ in range(num_time_masks):
        t = random.randint(0, time_mask_param)
        t0 = random.randint(0, max(0, T - t)) if T - t > 0 else 0
        features[:, t0:t0+t, :] = 0
    for _ in range(num_freq_masks):
        f = random.randint(0, freq_mask_param)
        f0 = random.randint(0, max(0, D - f)) if D - f > 0 else 0
        features[:, :, f0:f0+f] = 0
    return features

# %%
# ---------------------------
# Adapter module
# ---------------------------
class Adapter(nn.Module):
    def __init__(self, dim, bottleneck=128):
        super().__init__()
        self.down = nn.Linear(dim, bottleneck)
        self.relu = nn.ReLU()
        self.up = nn.Linear(bottleneck, dim)

    def forward(self, x):
        residual = x
        x = self.down(x)
        x = self.relu(x)
        x = self.up(x)
        return x + residual

# %%
# ---------------------------
# Custom head: Transformer encoder + linear -> vocab (CTC)
# ---------------------------
class CustomTransformerCTCHead(nn.Module):
    def __init__(self, input_dim: int, model_dim: int, num_layers: int, num_heads: int, dropout: float, vocab_size: int):
        super().__init__()
        self.input_dim = input_dim
        self.model_dim = model_dim
        self.vocab_size = vocab_size
        
        # Project input to model dimension if needed
        if input_dim != model_dim:
            self.input_proj = nn.Linear(input_dim, model_dim)
        else:
            self.input_proj = nn.Identity()
        
        # Transformer encoder layers
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=model_dim,
            nhead=num_heads,
            dim_feedforward=model_dim * 4,
            dropout=dropout,
            batch_first=True
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        
        # Output projection to vocabulary
        self.output_proj = nn.Linear(model_dim, vocab_size)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, features: torch.Tensor) -> torch.Tensor:
        x = self.input_proj(features)
        x = self.dropout(x)
        x = self.transformer(x)
        logits = self.output_proj(x)
        return logits

# %%
# ---------------------------
# Combined Model wrapper
# ---------------------------
class W2V2WithCustomHead(nn.Module):
    def __init__(self, pretrained_name: str, processor: Wav2Vec2Processor, tokenizer: Wav2Vec2CTCTokenizer,
                 freeze_w2v: bool=True, use_adapters: bool=True, adapter_dim: int=128,
                 trans_layers: int=4, trans_dim: int=768, trans_heads: int=8, dropout: float=0.1):
        super().__init__()
        self.processor = processor
        self.tokenizer = tokenizer
        self.vocab_size = len(tokenizer.get_vocab())

        # Base wav2vec model
        self.wav2vec = Wav2Vec2Model.from_pretrained(pretrained_name)
        self.wav2vec_feature_dim = self.wav2vec.config.hidden_size

        if freeze_w2v:
            for p in self.wav2vec.parameters():
                p.requires_grad = False

        self.use_adapters = use_adapters
        if use_adapters:
            self.adapter = Adapter(self.wav2vec_feature_dim, bottleneck=adapter_dim)
        else:
            self.adapter = None

        self.custom_head = CustomTransformerCTCHead(
            input_dim=self.wav2vec_feature_dim, 
            model_dim=trans_dim, 
            num_layers=trans_layers, 
            num_heads=trans_heads, 
            dropout=dropout, 
            vocab_size=self.vocab_size
        )

    def forward(self, input_values: torch.Tensor, attention_mask: Optional[torch.Tensor]=None, 
            labels: Optional[torch.Tensor]=None):
        
        # Debug input shapes
        print(f"Forward pass - input_values shape: {input_values.shape}")
        if labels is not None:
            print(f"Forward pass - labels shape: {labels.shape}")
        
        outputs = self.wav2vec(input_values, attention_mask=attention_mask)
        features = outputs.last_hidden_state
        
        if self.adapter is not None:
            features = self.adapter(features)

        logits = self.custom_head(features)
        print(f"Forward pass - logits shape: {logits.shape}")

        loss = None
        if labels is not None:
            # CTC loss computation
            log_probs = F.log_softmax(logits, dim=-1)
            
            # Get input lengths
            input_lengths = torch.full(
                size=(log_probs.shape[0],), 
                fill_value=log_probs.shape[1], 
                dtype=torch.long, 
                device=log_probs.device
            )
            
            # Get target lengths (exclude pad tokens which are ID=2)
            target_lengths = (labels != 2).sum(dim=-1)
            print(f"Target lengths: {target_lengths}")
            
            # Flatten labels for CTC loss
            targets_list = []
            for i, length in enumerate(target_lengths):
                valid_labels = [label.item() for label in labels[i, :length] if label.item() != 2]
                targets_list.extend(valid_labels)
            
            print(f"CTC targets: {len(targets_list)} tokens")
            
            if len(targets_list) > 0 and target_lengths.sum() > 0:
                targets = torch.tensor(targets_list, dtype=torch.long, device=logits.device)
                
                log_probs_t = log_probs.transpose(0, 1)
                
                ctc_loss_fn = nn.CTCLoss(
                    blank=0,
                    zero_infinity=True, 
                    reduction='mean'
                )
                
                target_lengths = torch.clamp(target_lengths, min=1)
                
                try:
                    loss = ctc_loss_fn(log_probs_t, targets, input_lengths, target_lengths)
                    print(f"CTC loss computed: {loss.item()}")
                    
                    if torch.isnan(loss):
                        print("Warning: NaN loss detected")
                        loss = torch.tensor(0.1, device=logits.device, requires_grad=True)
                        
                except Exception as e:
                    print(f"CTC loss computation failed: {e}")
                    loss = torch.tensor(0.1, device=logits.device, requires_grad=True)
            else:
                print("No valid targets for CTC loss")
                loss = torch.tensor(0.1, device=logits.device, requires_grad=True)

        return {
            'loss': loss,
            'logits': logits,
        }

# %%
# ---------------------------
# Data Collator
# ---------------------------
@dataclass
class DataCollatorCTCWithAugment:
    processor: Wav2Vec2Processor
    tokenizer: Wav2Vec2CTCTokenizer
    sample_rate: int = SAMPLE_RATE
    padding: bool = True
    apply_spec_augment: bool = True
    apply_audio_aug: bool = True
    min_audio_length: int = 1600

    def __call__(self, features: List[Dict[str, Any]]) -> Dict[str, Any]:
        input_values = []
        labels = []

        for f in features:
            try:
                # Get audio file path
                audio_path = f.get("audio_path", "")
                
                if not audio_path or not os.path.exists(audio_path):
                    print(f"Audio file not found: {audio_path}")
                    continue

                # Load audio using librosa
                if LIBROSA_AVAILABLE:
                    arr, sr = librosa.load(audio_path, sr=self.sample_rate)
                else:
                    print("librosa not available - cannot load audio")
                    continue

                # Ensure 1D array
                if arr.ndim > 1:
                    arr = arr.flatten()

                # More lenient minimum length check
                if len(arr) < 800:  # Reduced from 1600 to 800
                    print(f"Skipping very short audio: {len(arr)} samples")
                    continue

                # Process with wav2vec2
                inputs = self.processor(
                    arr,
                    sampling_rate=self.sample_rate,
                    return_tensors="pt",
                )
                
                input_tensor = inputs.input_values.squeeze()
                if input_tensor.dim() == 0:
                    input_tensor = input_tensor.unsqueeze(0)
                input_values.append(input_tensor)

                # Process text
                text = str(f.get("text", "")).lower().strip()
                if not text:
                    print("Skipping empty text")
                    continue

                # Character-level tokenization
                token_ids = []
                vocab = self.tokenizer.get_vocab()
                
                for char in text:
                    if char in vocab:
                        token_ids.append(vocab[char])
                    else:
                        token_ids.append(vocab.get("<unk>", 1))  # unk is ID=1

                if token_ids:
                    labels.append(torch.tensor(token_ids, dtype=torch.long))
                else:
                    print("No valid tokens found")

            except Exception as e:
                print(f"Error processing sample {f.get('audio_path', 'unknown')}: {e}")
                import traceback
                traceback.print_exc()
                continue

        # Handle empty batch - IMPROVED ERROR HANDLING
        if len(input_values) == 0 or len(labels) == 0:
            print(f"WARNING: Empty batch - input_values: {len(input_values)}, labels: {len(labels)}")
            print("This indicates a data loading problem!")
            
            # Create a minimal valid batch instead of dummy
            vocab = self.tokenizer.get_vocab()
            dummy_audio = torch.zeros(self.sample_rate // 2)  # 0.5 second of silence
            dummy_labels = torch.tensor([vocab.get("a", 3)], dtype=torch.long)  # Use a common character
            
            return {
                "input_values": dummy_audio.unsqueeze(0),
                "labels": dummy_labels.unsqueeze(0),
            }

        # Pad sequences
        input_values = nn.utils.rnn.pad_sequence(input_values, batch_first=True, padding_value=0.0)
        labels = nn.utils.rnn.pad_sequence(labels, batch_first=True, padding_value=2)  # pad token is ID=2

        print(f"Batch created: input_values shape: {input_values.shape}, labels shape: {labels.shape}")
        
        return {
            "input_values": input_values,
            "labels": labels,
        }

# %%
# # ---------------------------
# # Simple greedy + shallow fusion beam search (stub)
# # ---------------------------


# def greedy_decode_logits(logits: np.ndarray, tokenizer: PreTrainedTokenizerFast):
#     # logits: (B, T, V)
#     pred_ids = np.argmax(logits, axis=-1)
#     texts = []
#     for b in range(pred_ids.shape[0]):
#         ids = pred_ids[b].tolist()
#         # collapse repeats and remove pad (assume pad id is 0)
#         prev = None
#         out = []
#         for i in ids:
#             if i != prev and i != tokenizer.pad_token_id:
#                 out.append(i)
#             prev = i
#         texts.append(tokenizer.decode(out, clean_up_tokenization_spaces=False))
#     return texts


# # Shallow fusion requires an LM that can provide log-prob for token sequences. We'll provide a simple
# # integration hook using a pretrained causal LM (like GPT-2); in practice you'd prefer a kenlm or an ngram.


# class SimpleShallowFusionLM:
#     def __init__(self, model_name=LM_MODEL_NAME, device='cpu'):
#         try:
#             from transformers import AutoModelForCausalLM, AutoTokenizer
#             self.tokenizer = AutoTokenizer.from_pretrained(model_name)
#             self.model = AutoModelForCausalLM.from_pretrained(model_name).to(device)
#             self.model.eval()
#             self.device = device
#         except Exception as e:
#             print("Warning: Could not load LM for shallow fusion:", e)
#             self.model = None
#             self.tokenizer = None


#     def score_sequences(self, sequences: List[str]) -> List[float]:
#         # return average log-prob per token (negative loss)
#         if self.model is None:
#             return [0.0] * len(sequences)
#         enc = self.tokenizer(sequences, return_tensors='pt', padding=True).to(self.device)
#         with torch.no_grad():
#             out = self.model(**enc, labels=enc['input_ids'])
#             # negative loss gives log-prob
#             loss = out.loss.cpu().numpy()
#             # convert to per-sequence score; huggingface returns mean loss over tokens & batch
#             return [-float(loss)] * len(sequences)

# %%
# ---------------------------
# Dataset preparation
# ---------------------------
def prepare_dataset(tsv_path: str, audio_base: str) -> Dataset:
    import pandas as pd
    df = pd.read_csv(tsv_path, sep='\t', low_memory=False)
    
    # Handle non-standard column names
    columns = df.columns.tolist()
    if len(columns) >= 2:
        df = df.rename(columns={columns[0]: 'path', columns[1]: 'text'})
    
    if 'path' not in df.columns:
        raise ValueError('TSV must have at least 2 columns: audio path and text')

    # Create full audio paths
    def get_full_path(p):
        if os.path.isabs(p):
            return p
        else:
            base_path = os.path.join(audio_base, p)
            if os.path.exists(base_path):
                return base_path
            for ext in ['.wav', '.mp3', '.flac', '.ogg']:
                if os.path.exists(base_path + ext):
                    return base_path + ext
            return base_path
    
    df['audio_path'] = df['path'].apply(get_full_path)
    
    # Filter valid files
    initial_count = len(df)
    df = df[df['audio_path'].apply(os.path.exists)]
    final_count = len(df)
    
    print(f"Filtered dataset: {initial_count} -> {final_count} samples")
    
    if final_count == 0:
        raise ValueError("No valid audio files found!")
    
    # Keep as simple Dataset without Audio casting
    dataset = Dataset.from_pandas(df[['audio_path', 'text']])
    
    return dataset

# %%
def main():
    print("🚀 Starting Wav2Vec2 training with custom head...")
    
    # Load tokenizer and processor
    tokenizer = load_or_create_tokenizer(TSV_PATH, TOKENIZER_DIR)
    feature_extractor = Wav2Vec2FeatureExtractor(
        feature_size=1, 
        sampling_rate=SAMPLE_RATE, 
        padding_value=0.0, 
        do_normalize=True, 
        return_attention_mask=True
    )
    processor = Wav2Vec2Processor(feature_extractor=feature_extractor, tokenizer=tokenizer)
    
    print(f"✅ Tokenizer vocabulary size: {len(tokenizer.get_vocab())}")
    
    # Prepare dataset
    dataset = prepare_dataset(TSV_PATH, AUDIO_BASE)
    print(f"✅ Dataset loaded: {len(dataset)} samples")
    
    # DEBUG: Check what's in the first few samples
    print("DEBUG: First sample keys:", dataset[0].keys())
    print("DEBUG: First sample audio_path:", dataset[0]['audio_path'])
    print("DEBUG: First sample text:", dataset[0]['text'])
    
    # Check if audio files actually exist
    sample_paths = [dataset[i]['audio_path'] for i in range(min(5, len(dataset)))]
    existing_files = [path for path in sample_paths if os.path.exists(path)]
    print(f"DEBUG: Sample audio files exist: {len(existing_files)}/{len(sample_paths)}")
    
    # Split dataset
    dataset = dataset.train_test_split(test_size=0.1, seed=42)
    train_dataset = dataset['train']
    eval_dataset = dataset['test']
    
    print(f"Train dataset size: {len(train_dataset)}")
    print(f"Eval dataset size: {len(eval_dataset)}")
    
    # CREATE MODEL INSTANCE HERE - BEFORE USING IT
    print("🏗️ Creating model...")
    model = W2V2WithCustomHead(
        pretrained_name=PRETRAINED_W2V,
        processor=processor,
        tokenizer=tokenizer,
        freeze_w2v=FREEZE_W2V,
        use_adapters=USE_ADAPTERS,
        adapter_dim=ADAPTER_BOTTLENECK,
        trans_layers=CUSTOM_TRANSFORMER_LAYERS,
        trans_dim=CUSTOM_TRANSFORMER_DIM,
        trans_heads=CUSTOM_TRANSFORMER_HEADS,
        dropout=DROPOUT
    )
    model.to(DEVICE)
    print(f"✅ Model loaded on {DEVICE}")
    
    # Test data collator with a small batch
    data_collator = DataCollatorCTCWithAugment(
        processor=processor,
        tokenizer=tokenizer,
        sample_rate=SAMPLE_RATE,
        apply_spec_augment=False,  # Disable for debugging
        apply_audio_aug=False      # Disable for debugging
    )
    
    # Test with first few samples
    test_batch = [train_dataset[i] for i in range(min(3, len(train_dataset)))]
    print("Testing data collator...")
    try:
        batch = data_collator(test_batch)
        print(f"Test batch successful: {batch['input_values'].shape}")
    except Exception as e:
        print(f"Data collator test failed: {e}")
        import traceback
        traceback.print_exc()
        return
    
    # Metrics
    wer_metric = load('wer')
    
    def compute_metrics(pred):
        logits = pred.predictions
        if isinstance(logits, tuple):
            logits = logits[0]
            
        pred_ids = np.argmax(logits, axis=-1)
        label_ids = pred.label_ids
        
        pred_texts = []
        ref_texts = []
        
        for i in range(pred_ids.shape[0]):
            # Decode predictions (remove repeats and padding)
            pred_seq = []
            prev_id = None
            for token_id in pred_ids[i]:
                if token_id != prev_id and token_id != 0:  # 0 is blank token
                    pred_seq.append(token_id)
                prev_id = token_id
            pred_text = tokenizer.decode(pred_seq, skip_special_tokens=True)
            pred_texts.append(pred_text)
            
            # Decode references
            ref_seq = [t for t in label_ids[i] if t != 2]  # 2 is pad token
            ref_text = tokenizer.decode(ref_seq, skip_special_tokens=True)
            ref_texts.append(ref_text)
        
        wer_score = wer_metric.compute(predictions=pred_texts, references=ref_texts)
        return {"wer": wer_score}
    
    # Training arguments
    training_args = TrainingArguments(
        output_dir=OUTPUT_DIR,
        per_device_train_batch_size=BATCH_SIZE,
        per_device_eval_batch_size=BATCH_SIZE,
        num_train_epochs=EPOCHS,
        learning_rate=LR,
        warmup_steps=500,
        logging_steps=50,
        eval_steps=500,
        save_steps=500,
        eval_strategy="steps",
        save_total_limit=3,
        remove_unused_columns=False,
        dataloader_pin_memory=False,
        group_by_length=False,
        fp16=False,
        push_to_hub=False,
        report_to=None,
        max_grad_norm=1.0,
        dataloader_num_workers=0,
    )
    
    # Wrapper for HuggingFace Trainer
    class HFWrapperModel(nn.Module):
        def __init__(self, inner_model):
            super().__init__()
            self.inner = inner_model
        
        def forward(self, input_values=None, labels=None, **kwargs):
            outputs = self.inner(input_values=input_values, labels=labels)
            return outputs['loss'], outputs['logits']
    
    # NOW model is defined, so this will work
    wrapped_model = HFWrapperModel(model)
    
    # Trainer
    trainer = Trainer(
        model=wrapped_model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=eval_dataset,
        data_collator=data_collator,
        compute_metrics=compute_metrics,
    )
    
    # Train
    print("🏋️ Starting training...")
    trainer.train()
    
    # Final evaluation
    print("📊 Final evaluation...")
    metrics = trainer.evaluate()
    print("Final metrics:", metrics)
    
    # Save model
    trainer.save_model()
    processor.save_pretrained(OUTPUT_DIR)
    print(f"✅ Model saved to {OUTPUT_DIR}")

# %%
if __name__ == "__main__":
    main()
# Out:
# 🚀 Starting Wav2Vec2 training with custom head...
# ✅ Tokenizer vocabulary size: 72
# Filtered dataset: 2063 -> 2063 samples
# ✅ Dataset loaded: 2063 samples
# DEBUG: First sample keys: dict_keys(['audio_path', 'text'])
# DEBUG: First sample audio_path: /home/sahil_duwal/MajorProject/Dataset/ne_np_female/wavs/nep_0258_0461984530.wav
# DEBUG: First sample text: डिग्रा देवीको जन्म सुदूरपश्चिम नेपालको बझाङ जिल्लामा भएको हो
# DEBUG: Sample audio files exist: 5/5
# Train dataset size: 1856
# Eval dataset size: 207
# 🏗️ Creating model...
# ✅ Model loaded on cuda
# Testing data collator...
# Batch created: input_values shape: torch.Size([3, 55366]), labels shape: torch.Size([3, 44])
# Test batch successful: torch.Size([3, 55366])
# 🏋️ Starting training...
# Batch created: input_values shape: torch.Size([2, 50336]), labels shape: torch.Size([2, 45])
# Batch created: input_values shape: torch.Size([2, 111638]), labels shape: torch.Size([2, 93])
# Forward pass - input_values shape: torch.Size([2, 50336])
# Forward pass - labels shape: torch.Size([2, 45])
# Forward pass - logits shape: torch.Size([2, 157, 72])
# Target lengths: tensor([36, 45], device='cuda:0')
# CTC targets: 81 tokens
# CTC loss computed: 13.660125732421875
#     <div>
#
#       <progress value='3746' max='18560' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 3746/18560 27:09 < 1:47:27, 2.30 it/s, Epoch 4.04/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>5.162300</td>
#       <td>4.912009</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>6.603400</td>
#       <td>4.427245</td>
#       <td>0.998865</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>5.586900</td>
#       <td>4.361509</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>5.854900</td>
#       <td>4.379185</td>
#       <td>0.999432</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>5.766300</td>
#       <td>4.204469</td>
#       <td>1.002838</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>4.905100</td>
#       <td>4.113732</td>
#       <td>1.001703</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>6.349200</td>
#       <td>4.186207</td>
#       <td>1.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# Batch created: input_values shape: torch.Size([2, 64070]), labels shape: torch.Size([2, 44])
# Forward pass - input_values shape: torch.Size([2, 111638])
# Forward pass - labels shape: torch.Size([2, 93])
# Forward pass - logits shape: torch.Size([2, 348, 72])
# Target lengths: tensor([93, 49], device='cuda:0')
# CTC targets: 142 tokens
# CTC loss computed: 18.33310890197754
# Batch created: input_values shape: torch.Size([2, 96726]), labels shape: torch.Size([2, 73])
# Forward pass - input_values shape: torch.Size([2, 64070])
# Forward pass - labels shape: torch.Size([2, 44])
# Forward pass - logits shape: torch.Size([2, 199, 72])
# Target lengths: tensor([44, 35], device='cuda:0')
# CTC targets: 79 tokens
# CTC loss computed: 17.356586456298828
# Batch created: input_values shape: torch.Size([2, 115190]), labels shape: torch.Size([2, 79])
# Forward pass - input_values shape: torch.Size([2, 96726])
# Forward pass - labels shape: torch.Size([2, 73])
# Forward pass - logits shape: torch.Size([2, 302, 72])
# Target lengths: tensor([37, 73], device='cuda:0')
# CTC targets: 110 tokens
# CTC loss computed: 20.31753158569336
# Batch created: input_values shape: torch.Size([2, 67339]), labels shape: torch.Size([2, 39])
# Forward pass - input_values shape: torch.Size([2, 115190])
# Forward pass - labels shape: torch.Size([2, 79])
# Forward pass - logits shape: torch.Size([2, 359, 72])
# Target lengths: tensor([79, 42], device='cuda:0')
# CTC targets: 121 tokens
# CTC loss computed: 23.481910705566406
# Batch created: input_values shape: torch.Size([2, 145350]), labels shape: torch.Size([2, 97])
# Forward pass - input_values shape: torch.Size([2, 67339])
# Forward pass - labels shape: torch.Size([2, 39])
# Forward pass - logits shape: torch.Size([2, 210, 72])
# Target lengths: tensor([26, 39], device='cuda:0')
# CTC targets: 65 tokens
# CTC loss computed: 23.595775604248047
# Batch created: input_values shape: torch.Size([2, 92726]), labels shape: torch.Size([2, 85])
# Forward pass - input_values shape: torch.Size([2, 145350])
# Forward pass - labels shape: torch.Size([2, 97])
# Forward pass - logits shape: torch.Size([2, 453, 72])
# Target lengths: tensor([97, 14], device='cuda:0')
# CTC targets: 111 tokens
# CTC loss computed: 61.279232025146484
# Batch created: input_values shape: torch.Size([2, 70912]), labels shape: torch.Size([2, 51])
# Forward pass - input_values shape: torch.Size([2, 92726])
# Forward pass - labels shape: torch.Size([2, 85])
# Forward pass - logits shape: torch.Size([2, 289, 72])
# Target lengths: tensor([68, 85], device='cuda:0')
# CTC targets: 153 tokens
# CTC loss computed: 12.590899467468262
# Batch created: input_values shape: torch.Size([2, 82662]), labels shape: torch.Size([2, 55])
# Forward pass - input_values shape: torch.Size([2, 70912])
# Forward pass - labels shape: torch.Size([2, 51])
# Forward pass - logits shape: torch.Size([2, 221, 72])
# Target lengths: tensor([51, 49], device='cuda:0')
# CTC targets: 100 tokens
# CTC loss computed: 14.452730178833008
# Batch created: input_values shape: torch.Size([2, 84310]), labels shape: torch.Size([2, 58])
# Forward pass - input_values shape: torch.Size([2, 82662])
# Forward pass - labels shape: torch.Size([2, 55])
# Forward pass - logits shape: torch.Size([2, 258, 72])
# Target lengths: tensor([55, 54], device='cuda:0')
# CTC targets: 109 tokens
# CTC loss computed: 15.644268035888672
# Batch created: input_values shape: torch.Size([2, 105547]), labels shape: torch.Size([2, 68])
# Forward pass - input_values shape: torch.Size([2, 84310])
# Forward pass - labels shape: torch.Size([2, 58])
# Forward pass - logits shape: torch.Size([2, 263, 72])
# Target lengths: tensor([58, 28], device='cuda:0')
# CTC targets: 86 tokens
# CTC loss computed: 22.225120544433594
# Batch created: input_values shape: torch.Size([2, 99771]), labels shape: torch.Size([2, 62])
# Forward pass - input_values shape: torch.Size([2, 105547])
# Forward pass - labels shape: torch.Size([2, 68])
# Forward pass - logits shape: torch.Size([2, 329, 72])
# Target lengths: tensor([22, 68], device='cuda:0')
# CTC targets: 90 tokens
# CTC loss computed: 30.04150390625
# Batch created: input_values shape: torch.Size([2, 188987]), labels shape: torch.Size([2, 163])
# Forward pass - input_values shape: torch.Size([2, 99771])
# Forward pass - labels shape: torch.Size([2, 62])
# Forward pass - logits shape: torch.Size([2, 311, 72])
# Target lengths: tensor([45, 62], device='cuda:0')
# CTC targets: 107 tokens
# CTC loss computed: 19.882339477539062
# Batch created: input_values shape: torch.Size([2, 69792]), labels shape: torch.Size([2, 68])
# Forward pass - input_values shape: torch.Size([2, 188987])
# Forward pass - labels shape: torch.Size([2, 163])
# Forward pass - logits shape: torch.Size([2, 590, 72])
# Target lengths: tensor([109, 163], device='cuda:0')
# CTC targets: 272 tokens
# CTC loss computed: 13.752143859863281
# Batch created: input_values shape: torch.Size([2, 89691]), labels shape: torch.Size([2, 60])
# Forward pass - input_values shape: torch.Size([2, 69792])
# Forward pass - labels shape: torch.Size([2, 68])
# Forward pass - logits shape: torch.Size([2, 217, 72])
# Target lengths: tensor([68, 38], device='cuda:0')
# CTC targets: 106 tokens
# CTC loss computed: 13.567672729492188
# Batch created: input_values shape: torch.Size([2, 128006]), labels shape: torch.Size([2, 80])
# Forward pass - input_values shape: torch.Size([2, 89691])
# Forward pass - labels shape: torch.Size([2, 60])
# Forward pass - logits shape: torch.Size([2, 280, 72])
# Target lengths: tensor([60, 40], device='cuda:0')
# CTC targets: 100 tokens
# CTC loss computed: 16.578794479370117
# Batch created: input_values shape: torch.Size([2, 86176]), labels shape: torch.Size([2, 68])
# Forward pass - input_values shape: torch.Size([2, 128006])
# Forward pass - labels shape: torch.Size([2, 80])
# Forward pass - logits shape: torch.Size([2, 399, 72])
# Target lengths: tensor([80, 79], device='cuda:0')
# CTC targets: 159 tokens
# CTC loss computed: 14.254960060119629
# Batch created: input_values shape: torch.Size([2, 105227]), labels shape: torch.Size([2, 77])
# Forward pass - input_values shape: torch.Size([2, 86176])
# Forward pass - labels shape: torch.Size([2, 68])
# Forward pass - logits shape: torch.Size([2, 269, 72])
# Target lengths: tensor([68, 55], device='cuda:0')
# CTC targets: 123 tokens
# CTC loss computed: 12.468056678771973
# Batch created: input_values shape: torch.Size([2, 56208]), labels shape: torch.Size([2, 35])
# Forward pass - input_values shape: torch.Size([2, 105227])
# Forward pass - labels shape: torch.Size([2, 77])
# Forward pass - logits shape: torch.Size([2, 328, 72])
# Target lengths: tensor([67, 77], device='cuda:0')
# CTC targets: 144 tokens
# CTC loss computed: 12.39022445678711
# Batch created: input_values shape: torch.Size([2, 100128]), labels shape: torch.Size([2, 70])
# Forward pass - input_values shape: torch.Size([2, 56208])
# Forward pass - labels shape: torch.Size([2, 35])
# Forward pass - logits shape: torch.Size([2, 175, 72])
# Target lengths: tensor([35, 33], device='cuda:0')
# CTC targets: 68 tokens
# CTC loss computed: 13.053632736206055
# Batch created: input_values shape: torch.Size([2, 133328]), labels shape: torch.Size([2, 93])
# Forward pass - input_values shape: torch.Size([2, 100128])
# Forward pass - labels shape: torch.Size([2, 70])
# Forward pass - logits shape: torch.Size([2, 312, 72])
# Target lengths: tensor([70, 68], device='cuda:0')
# CTC targets: 138 tokens
# CTC loss computed: 12.850000381469727
# Batch created: input_values shape: torch.Size([2, 81184]), labels shape: torch.Size([2, 69])
# Forward pass - input_values shape: torch.Size([2, 133328])
# Forward pass - labels shape: torch.Size([2, 93])
# Forward pass - logits shape: torch.Size([2, 416, 72])
# Target lengths: tensor([93, 41], device='cuda:0')
# CTC targets: 134 tokens
# CTC loss computed: 24.238611221313477
# Batch created: input_values shape: torch.Size([2, 143014]), labels shape: torch.Size([2, 107])
# Forward pass - input_values shape: torch.Size([2, 81184])
# Forward pass - labels shape: torch.Size([2, 69])
# Forward pass - logits shape: torch.Size([2, 253, 72])
# Target lengths: tensor([69, 63], device='cuda:0')
# CTC targets: 132 tokens
# CTC loss computed: 9.153390884399414
# Batch created: input_values shape: torch.Size([2, 108955]), labels shape: torch.Size([2, 81])
# Forward pass - input_values shape: torch.Size([2, 143014])
# Forward pass - labels shape: torch.Size([2, 107])
# Forward pass - logits shape: torch.Size([2, 446, 72])
# Target lengths: tensor([ 83, 107], device='cuda:0')
# CTC targets: 190 tokens
# CTC loss computed: 9.692708015441895
# Batch created: input_values shape: torch.Size([2, 103995]), labels shape: torch.Size([2, 82])
# Forward pass - input_values shape: torch.Size([2, 108955])
# Forward pass - labels shape: torch.Size([2, 81])
# Forward pass - logits shape: torch.Size([2, 340, 72])
# Target lengths: tensor([44, 81], device='cuda:0')
# CTC targets: 125 tokens
# CTC loss computed: 15.906329154968262
# Batch created: input_values shape: torch.Size([2, 121819]), labels shape: torch.Size([2, 86])
# Forward pass - input_values shape: torch.Size([2, 103995])
# Forward pass - labels shape: torch.Size([2, 82])
# Forward pass - logits shape: torch.Size([2, 324, 72])
# Target lengths: tensor([58, 82], device='cuda:0')
# CTC targets: 140 tokens
# CTC loss computed: 8.662764549255371
# Batch created: input_values shape: torch.Size([2, 167878]), labels shape: torch.Size([2, 121])
# Forward pass - input_values shape: torch.Size([2, 121819])
# Forward pass - labels shape: torch.Size([2, 86])
# Forward pass - logits shape: torch.Size([2, 380, 72])
# Target lengths: tensor([86, 50], device='cuda:0')
# CTC targets: 136 tokens
# CTC loss computed: 15.168241500854492
# Batch created: input_values shape: torch.Size([2, 109739]), labels shape: torch.Size([2, 87])
# Forward pass - input_values shape: torch.Size([2, 167878])
# Forward pass - labels shape: torch.Size([2, 121])
# Forward pass - logits shape: torch.Size([2, 524, 72])
# Target lengths: tensor([121,  29], device='cuda:0')
# CTC targets: 150 tokens
# CTC loss computed: 13.826826095581055
# Batch created: input_values shape: torch.Size([2, 69307]), labels shape: torch.Size([2, 50])
# Forward pass - input_values shape: torch.Size([2, 109739])
# Forward pass - labels shape: torch.Size([2, 87])
# Forward pass - logits shape: torch.Size([2, 342, 72])
# Target lengths: tensor([87, 59], device='cuda:0')
# CTC targets: 146 tokens
# CTC loss computed: 7.9214887619018555
# Batch created: input_values shape: torch.Size([2, 91616]), labels shape: torch.Size([2, 71])
# Forward pass - input_values shape: torch.Size([2, 69307])
# Forward pass - labels shape: torch.Size([2, 50])
# Forward pass - logits shape: torch.Size([2, 216, 72])
# Target lengths: tensor([50, 42], device='cuda:0')
# CTC targets: 92 tokens
# CTC loss computed: 7.411617279052734
# Batch created: input_values shape: torch.Size([2, 138459]), labels shape: torch.Size([2, 116])
# Forward pass - input_values shape: torch.Size([2, 91616])
# Forward pass - labels shape: torch.Size([2, 71])
# Forward pass - logits shape: torch.Size([2, 286, 72])
# Target lengths: tensor([71, 60], device='cuda:0')
# CTC targets: 131 tokens
# CTC loss computed: 10.326789855957031
# Batch created: input_values shape: torch.Size([2, 89675]), labels shape: torch.Size([2, 93])
# Forward pass - input_values shape: torch.Size([2, 138459])
# Forward pass - labels shape: torch.Size([2, 116])
# Forward pass - logits shape: torch.Size([2, 432, 72])
# Target lengths: tensor([116,  43], device='cuda:0')
# CTC targets: 159 tokens
# CTC loss computed: 7.478879451751709
# Batch created: input_values shape: torch.Size([2, 76539]), labels shape: torch.Size([2, 73])
# Forward pass - input_values shape: torch.Size([2, 89675])
# Forward pass - labels shape: torch.Size([2, 93])
# Forward pass - logits shape: torch.Size([2, 279, 72])
# Target lengths: tensor([93, 38], device='cuda:0')
# CTC targets: 131 tokens
# CTC loss computed: 15.0399751663208
# Batch created: input_values shape: torch.Size([2, 142603]), labels shape: torch.Size([2, 94])
# Forward pass - input_values shape: torch.Size([2, 76539])
# Forward pass - labels shape: torch.Size([2, 73])
# Forward pass - logits shape: torch.Size([2, 238, 72])
# Target lengths: tensor([73, 26], device='cuda:0')
# CTC targets: 99 tokens
# CTC loss computed: 18.510873794555664
# Batch created: input_values shape: torch.Size([2, 102310]), labels shape: torch.Size([2, 73])
# Forward pass - input_values shape: torch.Size([2, 142603])
# Forward pass - labels shape: torch.Size([2, 94])
# Forward pass - logits shape: torch.Size([2, 445, 72])
# Target lengths: tensor([94, 94], device='cuda:0')
# CTC targets: 188 tokens
# CTC loss computed: 6.650008201599121
# Batch created: input_values shape: torch.Size([2, 48886]), labels shape: torch.Size([2, 36])
# Forward pass - input_values shape: torch.Size([2, 102310])
# Forward pass - labels shape: torch.Size([2, 73])
# Forward pass - logits shape: torch.Size([2, 319, 72])
# Target lengths: tensor([73, 33], device='cuda:0')
# CTC targets: 106 tokens
# CTC loss computed: 24.208114624023438
# Batch created: input_values shape: torch.Size([2, 98219]), labels shape: torch.Size([2, 73])
# Forward pass - input_values shape: torch.Size([2, 48886])
# Forward pass - labels shape: torch.Size([2, 36])
# Forward pass - logits shape: torch.Size([2, 152, 72])
# Target lengths: tensor([36, 22], device='cuda:0')
# CTC targets: 58 tokens
# CTC loss computed: 13.359260559082031
# Batch created: input_values shape: torch.Size([2, 49376]), labels shape: torch.Size([2, 45])
# Forward pass - input_values shape: torch.Size([2, 98219])
# Forward pass - labels shape: torch.Size([2, 73])
# Forward pass - logits shape: torch.Size([2, 306, 72])
# Target lengths: tensor([62, 73], device='cuda:0')
# CTC targets: 135 tokens
# CTC loss computed: 12.184183120727539
# Batch created: input_values shape: torch.Size([2, 46635]), labels shape: torch.Size([2, 37])
# Forward pass - input_values shape: torch.Size([2, 49376])
# Forward pass - labels shape: torch.Size([2, 45])
# Forward pass - logits shape: torch.Size([2, 154, 72])
# Target lengths: tensor([15, 45], device='cuda:0')
# CTC targets: 60 tokens
# CTC loss computed: 27.442951202392578
# Batch created: input_values shape: torch.Size([2, 167302]), labels shape: torch.Size([2, 106])
# Forward pass - input_values shape: torch.Size([2, 46635])
# Forward pass - labels shape: torch.Size([2, 37])
# Forward pass - logits shape: torch.Size([2, 145, 72])
# Target lengths: tensor([37, 27], device='cuda:0')
# CTC targets: 64 tokens
# CTC loss computed: 17.957530975341797
# Batch created: input_values shape: torch.Size([2, 88918]), labels shape: torch.Size([2, 64])
# Forward pass - input_values shape: torch.Size([2, 167302])
# Forward pass - labels shape: torch.Size([2, 106])
# Forward pass - logits shape: torch.Size([2, 522, 72])
# Target lengths: tensor([ 44, 106], device='cuda:0')
# CTC targets: 150 tokens
# CTC loss computed: 7.623424530029297
# Batch created: input_values shape: torch.Size([2, 60928]), labels shape: torch.Size([2, 39])
# Forward pass - input_values shape: torch.Size([2, 88918])
# Forward pass - labels shape: torch.Size([2, 64])
# Forward pass - logits shape: torch.Size([2, 277, 72])
# Target lengths: tensor([60, 64], device='cuda:0')
# CTC targets: 124 tokens
# CTC loss computed: 6.17201566696167
# Batch created: input_values shape: torch.Size([2, 83702]), labels shape: torch.Size([2, 75])
# Forward pass - input_values shape: torch.Size([2, 60928])
# Forward pass - labels shape: torch.Size([2, 39])
# Forward pass - logits shape: torch.Size([2, 190, 72])
# Target lengths: tensor([39, 33], device='cuda:0')
# CTC targets: 72 tokens
# CTC loss computed: 11.1726713180542
# Batch created: input_values shape: torch.Size([2, 93078]), labels shape: torch.Size([2, 70])
# Forward pass - input_values shape: torch.Size([2, 83702])
# Forward pass - labels shape: torch.Size([2, 75])
# Forward pass - logits shape: torch.Size([2, 261, 72])
# Target lengths: tensor([59, 75], device='cuda:0')
# CTC targets: 134 tokens
# CTC loss computed: 6.210491180419922
# Batch created: input_values shape: torch.Size([2, 82187]), labels shape: torch.Size([2, 76])
# Forward pass - input_values shape: torch.Size([2, 93078])
# Forward pass - labels shape: torch.Size([2, 70])
# Forward pass - logits shape: torch.Size([2, 290, 72])
# Target lengths: tensor([70, 52], device='cuda:0')
# CTC targets: 122 tokens
# CTC loss computed: 6.716453552246094
# Batch created: input_values shape: torch.Size([2, 65435]), labels shape: torch.Size([2, 55])
# Forward pass - input_values shape: torch.Size([2, 82187])
# Forward pass - labels shape: torch.Size([2, 76])
# Forward pass - logits shape: torch.Size([2, 256, 72])
# Target lengths: tensor([42, 76], device='cuda:0')
# CTC targets: 118 tokens
# CTC loss computed: 6.453775405883789
# Batch created: input_values shape: torch.Size([2, 92678]), labels shape: torch.Size([2, 75])
# Forward pass - input_values shape: torch.Size([2, 65435])
# Forward pass - labels shape: torch.Size([2, 55])
# Forward pass - logits shape: torch.Size([2, 204, 72])
# Target lengths: tensor([36, 55], device='cuda:0')
# CTC targets: 91 tokens
# CTC loss computed: 6.615433216094971
# Batch created: input_values shape: torch.Size([2, 173739]), labels shape: torch.Size([2, 121])
# Forward pass - input_values shape: torch.Size([2, 92678])
# Forward pass - labels shape: torch.Size([2, 75])
# Forward pass - logits shape: torch.Size([2, 289, 72])
# Target lengths: tensor([75, 28], device='cuda:0')
# CTC targets: 103 tokens
# CTC loss computed: 18.283523559570312
# Batch created: input_values shape: torch.Size([2, 96934]), labels shape: torch.Size([2, 62])
# Forward pass - input_values shape: torch.Size([2, 173739])
# Forward pass - labels shape: torch.Size([2, 121])
# Forward pass - logits shape: torch.Size([2, 542, 72])
# Target lengths: tensor([121,  69], device='cuda:0')
# CTC targets: 190 tokens
# CTC loss computed: 6.479166507720947
# Batch created: input_values shape: torch.Size([2, 70619]), labels shape: torch.Size([2, 50])
# Forward pass - input_values shape: torch.Size([2, 96934])
# Forward pass - labels shape: torch.Size([2, 62])
# Forward pass - logits shape: torch.Size([2, 302, 72])
# Target lengths: tensor([62, 55], device='cuda:0')
# CTC targets: 117 tokens
# CTC loss computed: 6.206587791442871
# Batch created: input_values shape: torch.Size([2, 53510]), labels shape: torch.Size([2, 40])
# Forward pass - input_values shape: torch.Size([2, 70619])
# Forward pass - labels shape: torch.Size([2, 50])
# Forward pass - logits shape: torch.Size([2, 220, 72])
# Target lengths: tensor([50, 19], device='cuda:0')
# CTC targets: 69 tokens
# CTC loss computed: 6.655435562133789
# Batch created: input_values shape: torch.Size([2, 72720]), labels shape: torch.Size([2, 58])
# Forward pass - input_values shape: torch.Size([2, 53510])
# Forward pass - labels shape: torch.Size([2, 40])
# Forward pass - logits shape: torch.Size([2, 166, 72])
# Target lengths: tensor([40, 29], device='cuda:0')
# CTC targets: 69 tokens
# CTC loss computed: 6.162400245666504
# Batch created: input_values shape: torch.Size([2, 64582]), labels shape: torch.Size([2, 55])
# Forward pass - input_values shape: torch.Size([2, 72720])
# Forward pass - labels shape: torch.Size([2, 58])
# Forward pass - logits shape: torch.Size([2, 227, 72])
# Target lengths: tensor([20, 58], device='cuda:0')
# CTC targets: 78 tokens
# CTC loss computed: 27.3120059967041
# Batch created: input_values shape: torch.Size([2, 97142]), labels shape: torch.Size([2, 67])
# Forward pass - input_values shape: torch.Size([2, 64582])
# Forward pass - labels shape: torch.Size([2, 55])
# Forward pass - logits shape: torch.Size([2, 201, 72])
# Target lengths: tensor([55, 40], device='cuda:0')
# CTC targets: 95 tokens
# CTC loss computed: 12.462482452392578
# Batch created: input_values shape: torch.Size([2, 94448]), labels shape: torch.Size([2, 68])
# Forward pass - input_values shape: torch.Size([2, 97142])
# Forward pass - labels shape: torch.Size([2, 67])
# Forward pass - logits shape: torch.Size([2, 303, 72])
# Target lengths: tensor([16, 67], device='cuda:0')
# CTC targets: 83 tokens
# CTC loss computed: 7.293274879455566
# Batch created: input_values shape: torch.Size([2, 70987]), labels shape: torch.Size([2, 54])
# Forward pass - input_values shape: torch.Size([2, 94448])
# Forward pass - labels shape: torch.Size([2, 68])
# Forward pass - logits shape: torch.Size([2, 294, 72])
# Target lengths: tensor([68, 41], device='cuda:0')
# CTC targets: 109 tokens
# CTC loss computed: 6.038479804992676
# Batch created: input_values shape: torch.Size([2, 64374]), labels shape: torch.Size([2, 61])
# Forward pass - input_values shape: torch.Size([2, 70987])
# Forward pass - labels shape: torch.Size([2, 54])
# Forward pass - logits shape: torch.Size([2, 221, 72])
# Target lengths: tensor([53, 54], device='cuda:0')
# CTC targets: 107 tokens
# CTC loss computed: 6.042926788330078
# Batch created: input_values shape: torch.Size([2, 63302]), labels shape: torch.Size([2, 58])
# Forward pass - input_values shape: torch.Size([2, 64374])
# Forward pass - labels shape: torch.Size([2, 61])
# Forward pass - logits shape: torch.Size([2, 200, 72])
# Target lengths: tensor([61, 35], device='cuda:0')
# CTC targets: 96 tokens
# CTC loss computed: 14.121201515197754
# Batch created: input_values shape: torch.Size([2, 65019]), labels shape: torch.Size([2, 49])
# Forward pass - input_values shape: torch.Size([2, 63302])
# Forward pass - labels shape: torch.Size([2, 58])
# Forward pass - logits shape: torch.Size([2, 197, 72])
# Target lengths: tensor([41, 58], device='cuda:0')
# CTC targets: 99 tokens
# CTC loss computed: 5.651323318481445
# Batch created: input_values shape: torch.Size([2, 109051]), labels shape: torch.Size([2, 77])
# Forward pass - input_values shape: torch.Size([2, 65019])
# Forward pass - labels shape: torch.Size([2, 49])
# Forward pass - logits shape: torch.Size([2, 202, 72])
# Target lengths: tensor([49, 27], device='cuda:0')
# CTC targets: 76 tokens
# CTC loss computed: 10.577160835266113
# Batch created: input_values shape: torch.Size([2, 94214]), labels shape: torch.Size([2, 71])
# Forward pass - input_values shape: torch.Size([2, 109051])
# Forward pass - labels shape: torch.Size([2, 77])
# Forward pass - logits shape: torch.Size([2, 340, 72])
# Target lengths: tensor([29, 77], device='cuda:0')
# CTC targets: 106 tokens
# CTC loss computed: 6.906512260437012
# Batch created: input_values shape: torch.Size([2, 120875]), labels shape: torch.Size([2, 91])
# Forward pass - input_values shape: torch.Size([2, 94214])
# Forward pass - labels shape: torch.Size([2, 71])
# Forward pass - logits shape: torch.Size([2, 294, 72])
# Target lengths: tensor([51, 71], device='cuda:0')
# CTC targets: 122 tokens
# CTC loss computed: 11.41781997680664
# Batch created: input_values shape: torch.Size([2, 114854]), labels shape: torch.Size([2, 75])
# Forward pass - input_values shape: torch.Size([2, 120875])
# Forward pass - labels shape: torch.Size([2, 91])
# Forward pass - logits shape: torch.Size([2, 377, 72])
# Target lengths: tensor([58, 91], device='cuda:0')
# CTC targets: 149 tokens
# CTC loss computed: 6.207069396972656
# Batch created: input_values shape: torch.Size([2, 83142]), labels shape: torch.Size([2, 66])
# Forward pass - input_values shape: torch.Size([2, 114854])
# Forward pass - labels shape: torch.Size([2, 75])
# Forward pass - logits shape: torch.Size([2, 358, 72])
# Target lengths: tensor([59, 75], device='cuda:0')
# CTC targets: 134 tokens
# CTC loss computed: 6.271896839141846
# Batch created: input_values shape: torch.Size([2, 98902]), labels shape: torch.Size([2, 69])
# Forward pass - input_values shape: torch.Size([2, 83142])
# Forward pass - labels shape: torch.Size([2, 66])
# Forward pass - logits shape: torch.Size([2, 259, 72])
# Target lengths: tensor([66, 64], device='cuda:0')
# CTC targets: 130 tokens
# CTC loss computed: 8.204107284545898
# Batch created: input_values shape: torch.Size([2, 110496]), labels shape: torch.Size([2, 90])
# Forward pass - input_values shape: torch.Size([2, 98902])
# Forward pass - labels shape: torch.Size([2, 69])
# Forward pass - logits shape: torch.Size([2, 308, 72])
# Target lengths: tensor([51, 69], device='cuda:0')
# CTC targets: 120 tokens
# CTC loss computed: 6.179591178894043
# Batch created: input_values shape: torch.Size([2, 121248]), labels shape: torch.Size([2, 87])
# Forward pass - input_values shape: torch.Size([2, 110496])
# Forward pass - labels shape: torch.Size([2, 90])
# Forward pass - logits shape: torch.Size([2, 345, 72])
# Target lengths: tensor([90, 69], device='cuda:0')
# CTC targets: 159 tokens
# CTC loss computed: 5.833474159240723
# Batch created: input_values shape: torch.Size([2, 183238]), labels shape: torch.Size([2, 137])
# Forward pass - input_values shape: torch.Size([2, 121248])
# Forward pass - labels shape: torch.Size([2, 87])
# Forward pass - logits shape: torch.Size([2, 378, 72])
# Target lengths: tensor([87, 27], device='cuda:0')
# CTC targets: 114 tokens
# CTC loss computed: 19.076648712158203
# Batch created: input_values shape: torch.Size([2, 70411]), labels shape: torch.Size([2, 64])
# Forward pass - input_values shape: torch.Size([2, 183238])
# Forward pass - labels shape: torch.Size([2, 137])
# Forward pass - logits shape: torch.Size([2, 572, 72])
# Target lengths: tensor([137,  27], device='cuda:0')
# CTC targets: 164 tokens
# CTC loss computed: 26.621959686279297
# Batch created: input_values shape: torch.Size([2, 59798]), labels shape: torch.Size([2, 46])
# Forward pass - input_values shape: torch.Size([2, 70411])
# Forward pass - labels shape: torch.Size([2, 64])
# Forward pass - logits shape: torch.Size([2, 219, 72])
# Target lengths: tensor([64, 20], device='cuda:0')
# CTC targets: 84 tokens
# CTC loss computed: 7.159768104553223
# Batch created: input_values shape: torch.Size([2, 59478]), labels shape: torch.Size([2, 53])
# Forward pass - input_values shape: torch.Size([2, 59798])
# Forward pass - labels shape: torch.Size([2, 46])
# Forward pass - logits shape: torch.Size([2, 186, 72])
# Target lengths: tensor([19, 46], device='cuda:0')
# CTC targets: 65 tokens
# CTC loss computed: 6.795003890991211
# Batch created: input_values shape: torch.Size([2, 75744]), labels shape: torch.Size([2, 66])
# Forward pass - input_values shape: torch.Size([2, 59478])
# Forward pass - labels shape: torch.Size([2, 53])
# Forward pass - logits shape: torch.Size([2, 185, 72])
# Target lengths: tensor([45, 53], device='cuda:0')
# CTC targets: 98 tokens
# CTC loss computed: 7.968717575073242
# Batch created: input_values shape: torch.Size([2, 76694]), labels shape: torch.Size([2, 59])
# Forward pass - input_values shape: torch.Size([2, 75744])
# Forward pass - labels shape: torch.Size([2, 66])
# Forward pass - logits shape: torch.Size([2, 236, 72])
# Target lengths: tensor([66, 23], device='cuda:0')
# CTC targets: 89 tokens
# CTC loss computed: 6.992481231689453
# Batch created: input_values shape: torch.Size([2, 118859]), labels shape: torch.Size([2, 101])
# Forward pass - input_values shape: torch.Size([2, 76694])
# Forward pass - labels shape: torch.Size([2, 59])
# Forward pass - logits shape: torch.Size([2, 239, 72])
# Target lengths: tensor([59, 50], device='cuda:0')
# CTC targets: 109 tokens
# CTC loss computed: 5.863333702087402
# Batch created: input_values shape: torch.Size([2, 116928]), labels shape: torch.Size([2, 88])
# Forward pass - input_values shape: torch.Size([2, 118859])
# Forward pass - labels shape: torch.Size([2, 101])
# Forward pass - logits shape: torch.Size([2, 371, 72])
# Target lengths: tensor([ 59, 101], device='cuda:0')
# CTC targets: 160 tokens
# CTC loss computed: 6.358551979064941
# Batch created: input_values shape: torch.Size([2, 86187]), labels shape: torch.Size([2, 61])
# Forward pass - input_values shape: torch.Size([2, 116928])
# Forward pass - labels shape: torch.Size([2, 88])
# Forward pass - logits shape: torch.Size([2, 365, 72])
# Target lengths: tensor([88, 38], device='cuda:0')
# CTC targets: 126 tokens
# CTC loss computed: 6.64097261428833
# Batch created: input_values shape: torch.Size([2, 65808]), labels shape: torch.Size([2, 45])
# Forward pass - input_values shape: torch.Size([2, 86187])
# Forward pass - labels shape: torch.Size([2, 61])
# Forward pass - logits shape: torch.Size([2, 269, 72])
# Target lengths: tensor([61, 54], device='cuda:0')
# CTC targets: 115 tokens
# CTC loss computed: 9.388731956481934
# Batch created: input_values shape: torch.Size([2, 57264]), labels shape: torch.Size([2, 37])
# Forward pass - input_values shape: torch.Size([2, 65808])
# Forward pass - labels shape: torch.Size([2, 45])
# Forward pass - logits shape: torch.Size([2, 205, 72])
# Target lengths: tensor([45, 40], device='cuda:0')
# CTC targets: 85 tokens
# CTC loss computed: 11.26720905303955
# Batch created: input_values shape: torch.Size([2, 143126]), labels shape: torch.Size([2, 103])
# Forward pass - input_values shape: torch.Size([2, 57264])
# Forward pass - labels shape: torch.Size([2, 37])
# Forward pass - logits shape: torch.Size([2, 178, 72])
# Target lengths: tensor([22, 37], device='cuda:0')
# CTC targets: 59 tokens
# CTC loss computed: 15.902079582214355
# Batch created: input_values shape: torch.Size([2, 133974]), labels shape: torch.Size([2, 107])
# Forward pass - input_values shape: torch.Size([2, 143126])
# Forward pass - labels shape: torch.Size([2, 103])
# Forward pass - logits shape: torch.Size([2, 447, 72])
# Target lengths: tensor([ 23, 103], device='cuda:0')
# CTC targets: 126 tokens
# CTC loss computed: 32.83955001831055
# Batch created: input_values shape: torch.Size([2, 112870]), labels shape: torch.Size([2, 82])
# Forward pass - input_values shape: torch.Size([2, 133974])
# Forward pass - labels shape: torch.Size([2, 107])
# Forward pass - logits shape: torch.Size([2, 418, 72])
# Target lengths: tensor([107, 104], device='cuda:0')
# CTC targets: 211 tokens
# CTC loss computed: 5.48076868057251
# Batch created: input_values shape: torch.Size([2, 124384]), labels shape: torch.Size([2, 99])
# Forward pass - input_values shape: torch.Size([2, 112870])
# Forward pass - labels shape: torch.Size([2, 82])
# Forward pass - logits shape: torch.Size([2, 352, 72])
# Target lengths: tensor([64, 82], device='cuda:0')
# CTC targets: 146 tokens
# CTC loss computed: 5.826449394226074
# Batch created: input_values shape: torch.Size([2, 104758]), labels shape: torch.Size([2, 83])
# Forward pass - input_values shape: torch.Size([2, 124384])
# Forward pass - labels shape: torch.Size([2, 99])
# Forward pass - logits shape: torch.Size([2, 388, 72])
# Target lengths: tensor([99, 72], device='cuda:0')
# CTC targets: 171 tokens
# CTC loss computed: 5.564748764038086
# Batch created: input_values shape: torch.Size([2, 60795]), labels shape: torch.Size([2, 45])
# Forward pass - input_values shape: torch.Size([2, 104758])
# Forward pass - labels shape: torch.Size([2, 83])
# Forward pass - logits shape: torch.Size([2, 327, 72])
# Target lengths: tensor([83, 26], device='cuda:0')
# CTC targets: 109 tokens
# CTC loss computed: 20.61907386779785
# Batch created: input_values shape: torch.Size([2, 141115]), labels shape: torch.Size([2, 97])
# Forward pass - input_values shape: torch.Size([2, 60795])
# Forward pass - labels shape: torch.Size([2, 45])
# Forward pass - logits shape: torch.Size([2, 189, 72])
# Target lengths: tensor([40, 45], device='cuda:0')
# CTC targets: 85 tokens
# CTC loss computed: 5.75211238861084
# Batch created: input_values shape: torch.Size([2, 84966]), labels shape: torch.Size([2, 59])
# Forward pass - input_values shape: torch.Size([2, 141115])
# Forward pass - labels shape: torch.Size([2, 97])
# Forward pass - logits shape: torch.Size([2, 440, 72])
# Target lengths: tensor([97, 32], device='cuda:0')
# CTC targets: 129 tokens
# CTC loss computed: 22.05418586730957
# Batch created: input_values shape: torch.Size([2, 64539]), labels shape: torch.Size([2, 48])
# Forward pass - input_values shape: torch.Size([2, 84966])
# Forward pass - labels shape: torch.Size([2, 59])
# Forward pass - logits shape: torch.Size([2, 265, 72])
# Target lengths: tensor([30, 59], device='cuda:0')
# CTC targets: 89 tokens
# CTC loss computed: 19.24213981628418
# Batch created: input_values shape: torch.Size([2, 73990]), labels shape: torch.Size([2, 64])
# Forward pass - input_values shape: torch.Size([2, 64539])
# Forward pass - labels shape: torch.Size([2, 48])
# Forward pass - logits shape: torch.Size([2, 201, 72])
# Target lengths: tensor([48, 37], device='cuda:0')
# CTC targets: 85 tokens
# CTC loss computed: 5.593228340148926
# Batch created: input_values shape: torch.Size([2, 47680]), labels shape: torch.Size([2, 33])
# Forward pass - input_values shape: torch.Size([2, 73990])
# Forward pass - labels shape: torch.Size([2, 64])
# Forward pass - logits shape: torch.Size([2, 230, 72])
# Target lengths: tensor([64, 21], device='cuda:0')
# CTC targets: 85 tokens
# CTC loss computed: 6.5988054275512695
# Batch created: input_values shape: torch.Size([2, 122400]), labels shape: torch.Size([2, 79])
# Forward pass - input_values shape: torch.Size([2, 47680])
# Forward pass - labels shape: torch.Size([2, 33])
# Forward pass - logits shape: torch.Size([2, 148, 72])
# Target lengths: tensor([33, 24], device='cuda:0')
# CTC targets: 57 tokens
# CTC loss computed: 5.643430709838867
# Batch created: input_values shape: torch.Size([2, 108960]), labels shape: torch.Size([2, 93])
# Forward pass - input_values shape: torch.Size([2, 122400])
# Forward pass - labels shape: torch.Size([2, 79])
# Forward pass - logits shape: torch.Size([2, 382, 72])
# Target lengths: tensor([79, 28], device='cuda:0')
# CTC targets: 107 tokens
# CTC loss computed: 21.725879669189453
# Batch created: input_values shape: torch.Size([2, 83840]), labels shape: torch.Size([2, 62])
# Forward pass - input_values shape: torch.Size([2, 108960])
# Forward pass - labels shape: torch.Size([2, 93])
# Forward pass - logits shape: torch.Size([2, 340, 72])
# Target lengths: tensor([30, 93], device='cuda:0')
# CTC targets: 123 tokens
# CTC loss computed: 6.671555042266846
# Batch created: input_values shape: torch.Size([2, 121782]), labels shape: torch.Size([2, 93])
# Forward pass - input_values shape: torch.Size([2, 83840])
# Forward pass - labels shape: torch.Size([2, 62])
# Forward pass - logits shape: torch.Size([2, 261, 72])
# Target lengths: tensor([62, 30], device='cuda:0')
# CTC targets: 92 tokens
# CTC loss computed: 15.279353141784668
# Batch created: input_values shape: torch.Size([2, 97600]), labels shape: torch.Size([2, 70])
# Forward pass - input_values shape: torch.Size([2, 121782])
# Forward pass - labels shape: torch.Size([2, 93])
# Forward pass - logits shape: torch.Size([2, 380, 72])
# Target lengths: tensor([93, 51], device='cuda:0')
# CTC targets: 144 tokens
# CTC loss computed: 13.740289688110352
# Batch created: input_values shape: torch.Size([2, 100603]), labels shape: torch.Size([2, 68])
# Forward pass - input_values shape: torch.Size([2, 97600])
# Forward pass - labels shape: torch.Size([2, 70])
# Forward pass - logits shape: torch.Size([2, 304, 72])
# Target lengths: tensor([60, 70], device='cuda:0')
# CTC targets: 130 tokens
# CTC loss computed: 5.893181324005127
# Batch created: input_values shape: torch.Size([2, 188726]), labels shape: torch.Size([2, 124])
# Forward pass - input_values shape: torch.Size([2, 100603])
# Forward pass - labels shape: torch.Size([2, 68])
# Forward pass - logits shape: torch.Size([2, 314, 72])
# Target lengths: tensor([37, 68], device='cuda:0')
# CTC targets: 105 tokens
# CTC loss computed: 6.140244007110596
# Batch created: input_values shape: torch.Size([2, 119840]), labels shape: torch.Size([2, 86])
# Forward pass - input_values shape: torch.Size([2, 188726])
# Forward pass - labels shape: torch.Size([2, 124])
# Forward pass - logits shape: torch.Size([2, 589, 72])
# Target lengths: tensor([ 42, 124], device='cuda:0')
# CTC targets: 166 tokens
# CTC loss computed: 7.314596652984619
# Batch created: input_values shape: torch.Size([2, 44598]), labels shape: torch.Size([2, 25])
# Forward pass - input_values shape: torch.Size([2, 119840])
# Forward pass - labels shape: torch.Size([2, 86])
# Forward pass - logits shape: torch.Size([2, 374, 72])
# Target lengths: tensor([42, 86], device='cuda:0')
# CTC targets: 128 tokens
# CTC loss computed: 5.975428581237793
# Batch created: input_values shape: torch.Size([2, 107600]), labels shape: torch.Size([2, 88])
# Forward pass - input_values shape: torch.Size([2, 44598])
# Forward pass - labels shape: torch.Size([2, 25])
# Forward pass - logits shape: torch.Size([2, 139, 72])
# Target lengths: tensor([25, 24], device='cuda:0')
# CTC targets: 49 tokens
# CTC loss computed: 12.36075496673584
# Batch created: input_values shape: torch.Size([2, 95894]), labels shape: torch.Size([2, 76])
# Forward pass - input_values shape: torch.Size([2, 107600])
# Forward pass - labels shape: torch.Size([2, 88])
# Forward pass - logits shape: torch.Size([2, 336, 72])
# Target lengths: tensor([45, 88], device='cuda:0')
# CTC targets: 133 tokens
# CTC loss computed: 5.727113723754883
# Batch created: input_values shape: torch.Size([2, 110123]), labels shape: torch.Size([2, 74])
# Forward pass - input_values shape: torch.Size([2, 95894])
# Forward pass - labels shape: torch.Size([2, 76])
# Forward pass - logits shape: torch.Size([2, 299, 72])
# Target lengths: tensor([55, 76], device='cuda:0')
# CTC targets: 131 tokens
# CTC loss computed: 5.659475326538086
# Batch created: input_values shape: torch.Size([2, 122144]), labels shape: torch.Size([2, 108])
# Forward pass - input_values shape: torch.Size([2, 110123])
# Forward pass - labels shape: torch.Size([2, 74])
# Forward pass - logits shape: torch.Size([2, 343, 72])
# Target lengths: tensor([44, 74], device='cuda:0')
# CTC targets: 118 tokens
# CTC loss computed: 5.75473690032959
# Batch created: input_values shape: torch.Size([2, 60998]), labels shape: torch.Size([2, 46])
# Forward pass - input_values shape: torch.Size([2, 122144])
# Forward pass - labels shape: torch.Size([2, 108])
# Forward pass - logits shape: torch.Size([2, 381, 72])
# Target lengths: tensor([ 31, 108], device='cuda:0')
# CTC targets: 139 tokens
# CTC loss computed: 6.325056076049805
# Batch created: input_values shape: torch.Size([2, 145878]), labels shape: torch.Size([2, 95])
# Forward pass - input_values shape: torch.Size([2, 60998])
# Forward pass - labels shape: torch.Size([2, 46])
# Forward pass - logits shape: torch.Size([2, 190, 72])
# Target lengths: tensor([30, 46], device='cuda:0')
# CTC targets: 76 tokens
# CTC loss computed: 15.254735946655273
# Batch created: input_values shape: torch.Size([2, 139286]), labels shape: torch.Size([2, 97])
# Forward pass - input_values shape: torch.Size([2, 145878])
# Forward pass - labels shape: torch.Size([2, 95])
# Forward pass - logits shape: torch.Size([2, 455, 72])
# Target lengths: tensor([95, 36], device='cuda:0')
# CTC targets: 131 tokens
# CTC loss computed: 26.66573715209961
# Batch created: input_values shape: torch.Size([2, 86379]), labels shape: torch.Size([2, 65])
# Forward pass - input_values shape: torch.Size([2, 139286])
# Forward pass - labels shape: torch.Size([2, 97])
# Forward pass - logits shape: torch.Size([2, 435, 72])
# Target lengths: tensor([97, 23], device='cuda:0')
# CTC targets: 120 tokens
# CTC loss computed: 36.85185241699219
# Batch created: input_values shape: torch.Size([2, 136208]), labels shape: torch.Size([2, 108])
# Forward pass - input_values shape: torch.Size([2, 86379])
# Forward pass - labels shape: torch.Size([2, 65])
# Forward pass - logits shape: torch.Size([2, 269, 72])
# Target lengths: tensor([65, 29], device='cuda:0')
# CTC targets: 94 tokens
# CTC loss computed: 18.854969024658203
# Batch created: input_values shape: torch.Size([2, 65835]), labels shape: torch.Size([2, 40])
# Forward pass - input_values shape: torch.Size([2, 136208])
# Forward pass - labels shape: torch.Size([2, 108])
# Forward pass - logits shape: torch.Size([2, 425, 72])
# Target lengths: tensor([ 85, 108], device='cuda:0')
# CTC targets: 193 tokens
# CTC loss computed: 5.606607913970947
# Batch created: input_values shape: torch.Size([2, 80395]), labels shape: torch.Size([2, 52])
# Forward pass - input_values shape: torch.Size([2, 65835])
# Forward pass - labels shape: torch.Size([2, 40])
# Forward pass - logits shape: torch.Size([2, 205, 72])
# Target lengths: tensor([32, 40], device='cuda:0')
# CTC targets: 72 tokens
# CTC loss computed: 6.203795433044434
# Batch created: input_values shape: torch.Size([2, 153702]), labels shape: torch.Size([2, 116])
# Forward pass - input_values shape: torch.Size([2, 80395])
# Forward pass - labels shape: torch.Size([2, 52])
# Forward pass - logits shape: torch.Size([2, 250, 72])
# Target lengths: tensor([52, 43], device='cuda:0')
# CTC targets: 95 tokens
# CTC loss computed: 10.149478912353516
# Batch created: input_values shape: torch.Size([2, 109835]), labels shape: torch.Size([2, 86])
# Forward pass - input_values shape: torch.Size([2, 153702])
# Forward pass - labels shape: torch.Size([2, 116])
# Forward pass - logits shape: torch.Size([2, 480, 72])
# Target lengths: tensor([116,  92], device='cuda:0')
# CTC targets: 208 tokens
# CTC loss computed: 5.788149833679199
# Batch created: input_values shape: torch.Size([2, 91707]), labels shape: torch.Size([2, 64])
# Forward pass - input_values shape: torch.Size([2, 109835])
# Forward pass - labels shape: torch.Size([2, 86])
# Forward pass - logits shape: torch.Size([2, 342, 72])
# Target lengths: tensor([63, 86], device='cuda:0')
# CTC targets: 149 tokens
# CTC loss computed: 5.838865280151367
# Batch created: input_values shape: torch.Size([2, 69275]), labels shape: torch.Size([2, 63])
# Forward pass - input_values shape: torch.Size([2, 91707])
# Forward pass - labels shape: torch.Size([2, 64])
# Forward pass - logits shape: torch.Size([2, 286, 72])
# Target lengths: tensor([64, 25], device='cuda:0')
# CTC targets: 89 tokens
# CTC loss computed: 16.853057861328125
# Batch created: input_values shape: torch.Size([2, 63979]), labels shape: torch.Size([2, 56])
# Forward pass - input_values shape: torch.Size([2, 69275])
# Forward pass - labels shape: torch.Size([2, 63])
# Forward pass - logits shape: torch.Size([2, 216, 72])
# Target lengths: tensor([26, 63], device='cuda:0')
# CTC targets: 89 tokens
# CTC loss computed: 13.057209014892578
# Batch created: input_values shape: torch.Size([2, 130235]), labels shape: torch.Size([2, 96])
# Forward pass - input_values shape: torch.Size([2, 63979])
# Forward pass - labels shape: torch.Size([2, 56])
# Forward pass - logits shape: torch.Size([2, 199, 72])
# Target lengths: tensor([49, 56], device='cuda:0')
# CTC targets: 105 tokens
# CTC loss computed: 5.1506667137146
# Batch created: input_values shape: torch.Size([2, 67750]), labels shape: torch.Size([2, 68])
# Forward pass - input_values shape: torch.Size([2, 130235])
# Forward pass - labels shape: torch.Size([2, 96])
# Forward pass - logits shape: torch.Size([2, 406, 72])
# Target lengths: tensor([96, 61], device='cuda:0')
# CTC targets: 157 tokens
# CTC loss computed: 10.310003280639648
# Batch created: input_values shape: torch.Size([2, 94416]), labels shape: torch.Size([2, 80])
# Forward pass - input_values shape: torch.Size([2, 67750])
# Forward pass - labels shape: torch.Size([2, 68])
# Forward pass - logits shape: torch.Size([2, 211, 72])
# Target lengths: tensor([21, 68], device='cuda:0')
# CTC targets: 89 tokens
# CTC loss computed: 6.946013450622559
# Batch created: input_values shape: torch.Size([2, 65851]), labels shape: torch.Size([2, 64])
# Forward pass - input_values shape: torch.Size([2, 94416])
# Forward pass - labels shape: torch.Size([2, 80])
# Forward pass - logits shape: torch.Size([2, 294, 72])
# Target lengths: tensor([20, 80], device='cuda:0')
# CTC targets: 100 tokens
# CTC loss computed: 8.022180557250977
# Batch created: input_values shape: torch.Size([2, 131142]), labels shape: torch.Size([2, 89])
# Forward pass - input_values shape: torch.Size([2, 65851])
# Forward pass - labels shape: torch.Size([2, 64])
# Forward pass - logits shape: torch.Size([2, 205, 72])
# Target lengths: tensor([26, 64], device='cuda:0')
# CTC targets: 90 tokens
# CTC loss computed: 10.935473442077637
# Batch created: input_values shape: torch.Size([2, 82731]), labels shape: torch.Size([2, 67])
# Forward pass - input_values shape: torch.Size([2, 131142])
# Forward pass - labels shape: torch.Size([2, 89])
# Forward pass - logits shape: torch.Size([2, 409, 72])
# Target lengths: tensor([69, 89], device='cuda:0')
# CTC targets: 158 tokens
# CTC loss computed: 6.2691802978515625
# Batch created: input_values shape: torch.Size([2, 99051]), labels shape: torch.Size([2, 87])
# Forward pass - input_values shape: torch.Size([2, 82731])
# Forward pass - labels shape: torch.Size([2, 67])
# Forward pass - logits shape: torch.Size([2, 258, 72])
# Target lengths: tensor([67, 60], device='cuda:0')
# CTC targets: 127 tokens
# CTC loss computed: 5.663997650146484
# Batch created: input_values shape: torch.Size([2, 100491]), labels shape: torch.Size([2, 83])
# Forward pass - input_values shape: torch.Size([2, 99051])
# Forward pass - labels shape: torch.Size([2, 87])
# Forward pass - logits shape: torch.Size([2, 309, 72])
# Target lengths: tensor([87, 50], device='cuda:0')
# CTC targets: 137 tokens
# CTC loss computed: 12.452194213867188
# Batch created: input_values shape: torch.Size([2, 129547]), labels shape: torch.Size([2, 95])
# Forward pass - input_values shape: torch.Size([2, 100491])
# Forward pass - labels shape: torch.Size([2, 83])
# Forward pass - logits shape: torch.Size([2, 313, 72])
# Target lengths: tensor([83, 40], device='cuda:0')
# CTC targets: 123 tokens
# CTC loss computed: 12.07999038696289
# Batch created: input_values shape: torch.Size([2, 65600]), labels shape: torch.Size([2, 51])
# Forward pass - input_values shape: torch.Size([2, 129547])
# Forward pass - labels shape: torch.Size([2, 95])
# Forward pass - logits shape: torch.Size([2, 404, 72])
# Target lengths: tensor([61, 95], device='cuda:0')
# CTC targets: 156 tokens
# CTC loss computed: 5.9572434425354
# Batch created: input_values shape: torch.Size([2, 118016]), labels shape: torch.Size([2, 90])
# Forward pass - input_values shape: torch.Size([2, 65600])
# Forward pass - labels shape: torch.Size([2, 51])
# Forward pass - logits shape: torch.Size([2, 204, 72])
# Target lengths: tensor([38, 51], device='cuda:0')
# CTC targets: 89 tokens
# CTC loss computed: 5.7158379554748535
# Batch created: input_values shape: torch.Size([2, 86048]), labels shape: torch.Size([2, 76])
# Forward pass - input_values shape: torch.Size([2, 118016])
# ...
# Forward pass - labels shape: torch.Size([2, 61])
# Forward pass - logits shape: torch.Size([2, 220, 72])
# Target lengths: tensor([24, 61], device='cuda:0')
# CTC targets: 85 tokens
# CTC loss computed: 4.957353591918945
# Batch created: input_values shape: torch.Size([2, 116379]), labels shape: torch.Size([2, 92])
# Forward pass - input_values shape: torch.Size([2, 86816])
# Forward pass - labels shape: torch.Size([2, 60])
# Forward pass - logits shape: torch.Size([2, 271, 72])
# Target lengths: tensor([60, 43], device='cuda:0')
# CTC targets: 103 tokens
# CTC loss computed: 3.9609460830688477
# Batch created: input_values shape: torch.Size([2, 132080]), labels shape: torch.Size([2, 98])
# Forward pass - input_values shape: torch.Size([2, 116379])
# Forward pass - labels shape: torch.Size([2, 92])
# Forward pass - logits shape: torch.Size([2, 363, 72])
# Target lengths: tensor([68, 92], device='cuda:0')
# CTC targets: 160 tokens
# CTC loss computed: 3.7478232383728027
# Batch created: input_values shape: torch.Size([2, 99787]), labels shape: torch.Size([2, 89])
# Forward pass - input_values shape: torch.Size([2, 132080])
# Forward pass - labels shape: torch.Size([2, 98])
# Forward pass - logits shape: torch.Size([2, 412, 72])
# Target lengths: tensor([29, 98], device='cuda:0')
# CTC targets: 127 tokens
# CTC loss computed: 4.115898609161377
# Batch created: input_values shape: torch.Size([2, 139344]), labels shape: torch.Size([2, 87])
# Forward pass - input_values shape: torch.Size([2, 99787])
# Forward pass - labels shape: torch.Size([2, 89])
# Forward pass - logits shape: torch.Size([2, 311, 72])
# Target lengths: tensor([58, 89], device='cuda:0')
# CTC targets: 147 tokens
# CTC loss computed: 3.6216611862182617
# Batch created: input_values shape: torch.Size([2, 83600]), labels shape: torch.Size([2, 74])
# Forward pass - input_values shape: torch.Size([2, 139344])
# Forward pass - labels shape: torch.Size([2, 87])
# Forward pass - logits shape: torch.Size([2, 435, 72])
# Target lengths: tensor([68, 87], device='cuda:0')
# CTC targets: 155 tokens
# CTC loss computed: 4.47998046875
# Batch created: input_values shape: torch.Size([2, 153862]), labels shape: torch.Size([2, 106])
# Forward pass - input_values shape: torch.Size([2, 83600])
# Forward pass - labels shape: torch.Size([2, 74])
# Forward pass - logits shape: torch.Size([2, 261, 72])
# Target lengths: tensor([74, 45], device='cuda:0')
# CTC targets: 119 tokens
# CTC loss computed: 3.5473341941833496
# Batch created: input_values shape: torch.Size([2, 81643]), labels shape: torch.Size([2, 66])
# Forward pass - input_values shape: torch.Size([2, 153862])
# Forward pass - labels shape: torch.Size([2, 106])
# Forward pass - logits shape: torch.Size([2, 480, 72])
# Target lengths: tensor([ 87, 106], device='cuda:0')
# CTC targets: 193 tokens
# CTC loss computed: 3.648897886276245
# Batch created: input_values shape: torch.Size([2, 148534]), labels shape: torch.Size([2, 106])
# Forward pass - input_values shape: torch.Size([2, 81643])
# Forward pass - labels shape: torch.Size([2, 66])
# Forward pass - logits shape: torch.Size([2, 254, 72])
# Target lengths: tensor([35, 66], device='cuda:0')
# CTC targets: 101 tokens
# CTC loss computed: 3.464306116104126
# Batch created: input_values shape: torch.Size([2, 87627]), labels shape: torch.Size([2, 68])
# Forward pass - input_values shape: torch.Size([2, 148534])
# Forward pass - labels shape: torch.Size([2, 106])
# Forward pass - logits shape: torch.Size([2, 463, 72])
# Target lengths: tensor([ 20, 106], device='cuda:0')
# CTC targets: 126 tokens
# CTC loss computed: 4.951467990875244
# Batch created: input_values shape: torch.Size([2, 70966]), labels shape: torch.Size([2, 66])
# Forward pass - input_values shape: torch.Size([2, 87627])
# Forward pass - labels shape: torch.Size([2, 68])
# Forward pass - logits shape: torch.Size([2, 273, 72])
# Target lengths: tensor([68, 28], device='cuda:0')
# CTC targets: 96 tokens
# CTC loss computed: 3.5801424980163574
# Batch created: input_values shape: torch.Size([2, 58710]), labels shape: torch.Size([2, 55])
# Forward pass - input_values shape: torch.Size([2, 70966])
# Forward pass - labels shape: torch.Size([2, 66])
# Forward pass - logits shape: torch.Size([2, 221, 72])
# Target lengths: tensor([48, 66], device='cuda:0')
# CTC targets: 114 tokens
# CTC loss computed: 3.773930549621582
# Batch created: input_values shape: torch.Size([2, 78560]), labels shape: torch.Size([2, 65])
# Forward pass - input_values shape: torch.Size([2, 58710])
# Forward pass - labels shape: torch.Size([2, 55])
# Forward pass - logits shape: torch.Size([2, 183, 72])
# Target lengths: tensor([38, 55], device='cuda:0')
# CTC targets: 93 tokens
# CTC loss computed: 3.576474189758301
# Batch created: input_values shape: torch.Size([2, 84315]), labels shape: torch.Size([2, 65])
# Forward pass - input_values shape: torch.Size([2, 78560])
# Forward pass - labels shape: torch.Size([2, 65])
# Forward pass - logits shape: torch.Size([2, 245, 72])
# Target lengths: tensor([39, 65], device='cuda:0')
# CTC targets: 104 tokens
# CTC loss computed: 3.9951751232147217
# Batch created: input_values shape: torch.Size([2, 102240]), labels shape: torch.Size([2, 71])
# Forward pass - input_values shape: torch.Size([2, 84315])
# Forward pass - labels shape: torch.Size([2, 65])
# Forward pass - logits shape: torch.Size([2, 263, 72])
# Target lengths: tensor([65, 36], device='cuda:0')
# CTC targets: 101 tokens
# CTC loss computed: 3.701265335083008
# Batch created: input_values shape: torch.Size([2, 65718]), labels shape: torch.Size([2, 50])
# Forward pass - input_values shape: torch.Size([2, 102240])
# Forward pass - labels shape: torch.Size([2, 71])
# Forward pass - logits shape: torch.Size([2, 319, 72])
# Target lengths: tensor([68, 71], device='cuda:0')
# CTC targets: 139 tokens
# CTC loss computed: 4.024935245513916
# Batch created: input_values shape: torch.Size([2, 136395]), labels shape: torch.Size([2, 93])
# Forward pass - input_values shape: torch.Size([2, 65718])
# Forward pass - labels shape: torch.Size([2, 50])
# Forward pass - logits shape: torch.Size([2, 205, 72])
# Target lengths: tensor([43, 50], device='cuda:0')
# CTC targets: 93 tokens
# CTC loss computed: 3.622511863708496
# Batch created: input_values shape: torch.Size([2, 94267]), labels shape: torch.Size([2, 79])
# Forward pass - input_values shape: torch.Size([2, 136395])
# Forward pass - labels shape: torch.Size([2, 93])
# Forward pass - logits shape: torch.Size([2, 425, 72])
# Target lengths: tensor([93, 59], device='cuda:0')
# CTC targets: 152 tokens
# CTC loss computed: 3.541045904159546
# Batch created: input_values shape: torch.Size([2, 70416]), labels shape: torch.Size([2, 59])
# Forward pass - input_values shape: torch.Size([2, 94267])
# Forward pass - labels shape: torch.Size([2, 79])
# Forward pass - logits shape: torch.Size([2, 294, 72])
# Target lengths: tensor([23, 79], device='cuda:0')
# CTC targets: 102 tokens
# CTC loss computed: 10.983945846557617
# Batch created: input_values shape: torch.Size([2, 110496]), labels shape: torch.Size([2, 90])
# Forward pass - input_values shape: torch.Size([2, 70416])
# Forward pass - labels shape: torch.Size([2, 59])
# Forward pass - logits shape: torch.Size([2, 219, 72])
# Target lengths: tensor([59, 25], device='cuda:0')
# CTC targets: 84 tokens
# CTC loss computed: 3.3242130279541016
# Batch created: input_values shape: torch.Size([2, 43115]), labels shape: torch.Size([2, 30])
# Forward pass - input_values shape: torch.Size([2, 110496])
# Forward pass - labels shape: torch.Size([2, 90])
# Forward pass - logits shape: torch.Size([2, 345, 72])
# Target lengths: tensor([47, 90], device='cuda:0')
# CTC targets: 137 tokens
# CTC loss computed: 3.728266477584839
# Batch created: input_values shape: torch.Size([2, 82187]), labels shape: torch.Size([2, 76])
# Forward pass - input_values shape: torch.Size([2, 43115])
# Forward pass - labels shape: torch.Size([2, 30])
# Forward pass - logits shape: torch.Size([2, 134, 72])
# Target lengths: tensor([27, 30], device='cuda:0')
# CTC targets: 57 tokens
# CTC loss computed: 2.9928269386291504
# Batch created: input_values shape: torch.Size([2, 130235]), labels shape: torch.Size([2, 96])
# Forward pass - input_values shape: torch.Size([2, 82187])
# Forward pass - labels shape: torch.Size([2, 76])
# Forward pass - logits shape: torch.Size([2, 256, 72])
# Target lengths: tensor([76, 23], device='cuda:0')
# CTC targets: 99 tokens
# CTC loss computed: 12.763849258422852
# Batch created: input_values shape: torch.Size([2, 77003]), labels shape: torch.Size([2, 68])
# Forward pass - input_values shape: torch.Size([2, 130235])
# Forward pass - labels shape: torch.Size([2, 96])
# Forward pass - logits shape: torch.Size([2, 406, 72])
# Target lengths: tensor([36, 96], device='cuda:0')
# CTC targets: 132 tokens
# CTC loss computed: 4.047244071960449
# Batch created: input_values shape: torch.Size([2, 102299]), labels shape: torch.Size([2, 78])
# Forward pass - input_values shape: torch.Size([2, 77003])
# Forward pass - labels shape: torch.Size([2, 68])
# Forward pass - logits shape: torch.Size([2, 240, 72])
# Target lengths: tensor([31, 68], device='cuda:0')
# CTC targets: 99 tokens
# CTC loss computed: 3.6932404041290283
# Batch created: input_values shape: torch.Size([2, 71456]), labels shape: torch.Size([2, 62])
# Forward pass - input_values shape: torch.Size([2, 102299])
# Forward pass - labels shape: torch.Size([2, 78])
# Forward pass - logits shape: torch.Size([2, 319, 72])
# Target lengths: tensor([44, 78], device='cuda:0')
# CTC targets: 122 tokens
# CTC loss computed: 3.486323833465576
# Batch created: input_values shape: torch.Size([2, 70448]), labels shape: torch.Size([2, 63])
# Forward pass - input_values shape: torch.Size([2, 71456])
# Forward pass - labels shape: torch.Size([2, 62])
# Forward pass - logits shape: torch.Size([2, 223, 72])
# Target lengths: tensor([27, 62], device='cuda:0')
# CTC targets: 89 tokens
# CTC loss computed: 3.6576390266418457
# Batch created: input_values shape: torch.Size([2, 117579]), labels shape: torch.Size([2, 98])
# Forward pass - input_values shape: torch.Size([2, 70448])
# Forward pass - labels shape: torch.Size([2, 63])
# Forward pass - logits shape: torch.Size([2, 219, 72])
# Target lengths: tensor([63, 35], device='cuda:0')
# CTC targets: 98 tokens
# CTC loss computed: 3.511200189590454
# Batch created: input_values shape: torch.Size([2, 160955]), labels shape: torch.Size([2, 116])
# Forward pass - input_values shape: torch.Size([2, 117579])
# Forward pass - labels shape: torch.Size([2, 98])
# Forward pass - logits shape: torch.Size([2, 367, 72])
# Target lengths: tensor([98, 59], device='cuda:0')
# CTC targets: 157 tokens
# CTC loss computed: 3.7530174255371094
# Batch created: input_values shape: torch.Size([2, 122304]), labels shape: torch.Size([2, 83])
# Forward pass - input_values shape: torch.Size([2, 160955])
# Forward pass - labels shape: torch.Size([2, 116])
# Forward pass - logits shape: torch.Size([2, 502, 72])
# Target lengths: tensor([ 25, 116], device='cuda:0')
# CTC targets: 141 tokens
# CTC loss computed: 4.115309715270996
# Batch created: input_values shape: torch.Size([2, 79638]), labels shape: torch.Size([2, 58])
# Forward pass - input_values shape: torch.Size([2, 122304])
# Forward pass - labels shape: torch.Size([2, 83])
# Forward pass - logits shape: torch.Size([2, 381, 72])
# Target lengths: tensor([83, 67], device='cuda:0')
# CTC targets: 150 tokens
# CTC loss computed: 4.364201068878174
# Batch created: input_values shape: torch.Size([2, 134928]), labels shape: torch.Size([2, 92])
# Forward pass - input_values shape: torch.Size([2, 79638])
# Forward pass - labels shape: torch.Size([2, 58])
# Forward pass - logits shape: torch.Size([2, 248, 72])
# Target lengths: tensor([57, 58], device='cuda:0')
# CTC targets: 115 tokens
# CTC loss computed: 3.6399550437927246
# Batch created: input_values shape: torch.Size([2, 93462]), labels shape: torch.Size([2, 56])
# Forward pass - input_values shape: torch.Size([2, 134928])
# Forward pass - labels shape: torch.Size([2, 92])
# Forward pass - logits shape: torch.Size([2, 421, 72])
# Target lengths: tensor([92, 41], device='cuda:0')
# CTC targets: 133 tokens
# CTC loss computed: 3.608628749847412
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# Cell In[15], line 158, in main()
#     156 # Train
#     157 print("🏋️ Starting training...")
# --> 158 trainer.train()
#     160 # Final evaluation
#     161 print("📊 Final evaluation...")
#
# File ~/MajorProject/Major/lib/python3.10/site-packages/transformers/trainer.py:2238, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2236         hf_hub_utils.enable_progress_bars()
#    2237 else:
# -> 2238     return inner_training_loop(
#    2239         args=args,
#    2240         resume_from_checkpoint=resume_from_checkpoint,
#    2241         trial=trial,
#    2242         ignore_keys_for_eval=ignore_keys_for_eval,
#    2243     )
#
# File ~/MajorProject/Major/lib/python3.10/site-packages/transformers/trainer.py:2582, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2575 context = (
#    2576     functools.partial(self.accelerator.no_sync, model=model)
#    2577     if i != len(batch_samples) - 1
#    2578     and self.accelerator.distributed_type != DistributedType.DEEPSPEED
#    2579     else contextlib.nullcontext
#    2580 )
#    2581 with context():
# -> 2582     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2584 if (
#    2585     args.logging_nan_inf_filter
#    2586     and not is_torch_xla_available()
#    2587     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    2588 ):
#    2589     # if loss is nan or inf simply add the average of previous logged losses
#    2590     tr_loss = tr_loss + tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File ~/MajorProject/Major/lib/python3.10/site-packages/transformers/trainer.py:3845, in Trainer.training_step(***failed resolving arguments***)
#    3842 if self.accelerator.distributed_type == DistributedType.DEEPSPEED:
#    3843     kwargs["scale_wrt_gas"] = False
# -> 3845 self.accelerator.backward(loss, **kwargs)
#    3847 return loss.detach()
#
# File ~/MajorProject/Major/lib/python3.10/site-packages/accelerate/accelerator.py:2734, in Accelerator.backward(self, loss, **kwargs)
#    2732     self.lomo_backward(loss, learning_rate)
#    2733 else:
# -> 2734     loss.backward(**kwargs)
#
# File ~/MajorProject/Major/lib/python3.10/site-packages/torch/_tensor.py:647, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     637 if has_torch_function_unary(self):
#     638     return handle_torch_function(
#     639         Tensor.backward,
#     640         (self,),
#    (...)
#     645         inputs=inputs,
#     646     )
# --> 647 torch.autograd.backward(
#     648     self, gradient, retain_graph, create_graph, inputs=inputs
#     649 )
#
# File ~/MajorProject/Major/lib/python3.10/site-packages/torch/autograd/__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File ~/MajorProject/Major/lib/python3.10/site-packages/torch/autograd/graph.py:829, in _engine_run_backward(t_outputs, *args, **kwargs)
#     827     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     828 try:
# --> 829     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     830         t_outputs, *args, **kwargs
#     831     )  # Calls into the C++ engine to run the backward pass
#     832 finally:
#     833     if attach_logging_hooks:
#
# KeyboardInterrupt:
